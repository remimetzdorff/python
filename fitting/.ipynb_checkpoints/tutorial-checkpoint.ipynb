# %%
# %pylab qt
# %matplotlib inline
import fitting
import pandas
import random as rd

def noise(n, scale=1):
    data = []
    for i in range(n):
        number = scale * (rd.triangular()-0.5)*2
        data.append(number)
    return np.array(data)

fig = plt.figure(figsize=(12,12))
sps = (3,3)
axes = []
for i in range(sps[0]*sps[1]):
    nrow = i//sps[0]
    ncol = i%sps[1]
    axes.append(plt.subplot2grid(sps, (nrow,ncol)))

funcs = ["exponential", "exponential_offset", "gaussian", "linear", "sin", "sinc", "sinc_squarred"]
while len(funcs) < len(axes):
    funcs.append(None)

for ax, func in zip(axes, funcs):
    if func is not None:
        if "exponential" in func:
            xmin, xmax = -5, 1
        elif "sinc" in func:
            xmin, xmax = -1, 3
        elif "gaussian" in func:
            xmin, xmax = -3, 5
        else:
            xmin, xmax = -1, 1
        x     = np.linspace(xmin, xmax, 201)
        xfit  = x
        y     = np.zeros(len(x))
        noisy = noise(len(x), 0.01)
        uy = noisy
        fitter = fitting.Fit(func, x=x, y=y, uy=uy)
        params = np.ones(fitter.number_of_fitparams)*-np.pi
        y = fitter.func(x, *params) + noisy
        ax.plot(x, y, "-C0", alpha=0.5, label="data")
        fitter = fitting.Fit(func, x=x, y=y, uy=uy)
        y_guess = fitter.func(x, *fitter.guess_params())
        #print(fitter.guess_params())
        ax.plot(x, y_guess, "-C1", alpha=0.5, label="guess")
        fit_params, ufit_params = fitter.fit(manualguess_params=None, verbosemode=False)
        yfit = fitter.func(xfit, *fit_params)
        ax.plot(xfit, yfit, "-k", label="fit")
        subtitle = ""
        for key in fitter.params_key:
            subtitle += key+", "
        ax.set_title(func+"\n"+subtitle[:-2])
        ax.legend(loc="upper left", prop={"size":10})
plt.tight_layout()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Create false data and plot them
noise_scale = .01
params = [1, 1, 1]
x  = np.linspace(-5, 1, 51)
uy = np.ones(len(x)) * noise_scale
y  = params[1]*np.exp(params[0]*x) + noise(len(x), noise_scale) + params[2]
plt.errorbar(x, y, yerr=uy, fmt="o")

#Calculate best params for linear fit and plot fit curve
fitter = fitting.Fit("exponential_offset", x=x, y=y, uy=uy)

print(fitter._guessfunction(fitter))
fit_params, ufit_params = fitter.fit(manualguess_params=None, verbosemode=True)
yfit = fitter.func(x, *fit_params)
plt.plot(x, yfit)
# Out:
# [[618.1199999999999, 739.2349926367068], [739.2349926367068, 894.8503204491227]]
# [[51, 23.991251675341854], [23.991251675341854, 34.74881964231272]]
# [1.0030739294054545, 0.9962113830743509, 1.0019611741935026]
# [1.0030739294054545, 0.9962113830743509, 1.0019611741935026]
# [[618.1199999999999, 739.2349926367068], [739.2349926367068, 894.8503204491227]]
# [[51, 23.991251675341854], [23.991251675341854, 34.74881964231272]]
# [1.0030739294054545, 0.9962113830743509, 1.0019611741935026]
# ##### Fit results #####
# FIT FUNCTION: exponential_offset
# RAW
#         params_key      : ['scale', 'alpha', 'offset']
#         optimised params: [0.99945294 0.99897469 1.00057739]
#         uncertainties   : [0.00421102 0.00463093 0.00231757]
#         chi2r           : 0.22501545225699063
#         r2              : 0.9999536183010614
# READABLE
#         scale      = (9.99 +/- 0.04) * 1e-1
#         alpha      = (9.99 +/- 0.05) * 1e-1
#         offset     = (1.001 +/- 0.002) * 1e0
# #######################

# %% [markdown]
# # Linear

# %%
#Create false data and plot them
x  = np.linspace(0, 10, 21)
y  = np.pi*x+50 + noise(len(x), 2)
x += noise(len(x), 0.5) 
ux = np.ones(len(x))*0.25
uy = np.ones(len(x))*1

plt.errorbar(x, y, xerr=ux, yerr=uy, fmt="o")

#Calculate best params for linear fit and plot fit curve
fitter = fitting.Fit("linear", x=x, y=y, uy=uy, ux=ux)
fit_params, ufit_params = fitter.fit(manualguess_params=None, verbosemode=True)
yfit = fitter.func(x, *fit_params)
plt.plot(x, yfit)
# Out:
# ##### Fit results #####
# FIT FUNCTION: linear
# RAW
#         params_key      : ['slope', 'y0']
#         optimised params: [ 3.14658879 50.13734426]
#         uncertainties   : [0.09033001 0.52966001]
#         chi2r           : 0.7087164968997367
#         r2              : 0.9888190515513754
# READABLE
#         slope      = (3.15 +/- 0.09) * 1e0
#         y0         = (5.01 +/- 0.05) * 1e1
# #######################

# %%
#Also works with pandas.series

data = pandas.Series(y, index=x)
plt.errorbar(x, y, xerr=ux, yerr=uy, fmt="o")

#Calculate best params for linear fit and plot fit curve
fitter = fitting.Fit("linear", data=data, uy=uy, ux=ux)
fit_params, ufit_params = fitter.fit(manualguess_params=None, verbosemode=True)
yfit = fitter.func(x, *fit_params)
plt.plot(x, yfit)
# Out:
# ##### Fit results #####
# FIT FUNCTION: linear
# RAW
#         params_key      : ['slope', 'y0']
#         optimised params: [ 3.14658879 50.13734426]
#         uncertainties   : [0.09033001 0.52966001]
#         chi2r           : 0.7087164968997367
#         r2              : 0.9888190515513754
# READABLE
#         slope      = (3.15 +/- 0.09) * 1e0
#         y0         = (5.01 +/- 0.05) * 1e1
# #######################

# %% [markdown]
# # Functions available

# %%
fig = plt.figure(figsize=(12,12))
sps = (3,3)
axes = []
for i in range(sps[0]*sps[1]):
    nrow = i//sps[0]
    ncol = i%sps[1]
    axes.append(plt.subplot2grid(sps, (nrow,ncol)))

funcs = ["exponential", "exponential_offset", "gaussian", "linear", "sin", "sinc", "sinc_squarred"]
while len(funcs) < len(axes):
    funcs.append(None)

for ax, func in zip(axes, funcs):
    if func is not None:
        if "exponential" in func:
            xmin, xmax = -5, 1
        elif "sinc" in func:
            xmin, xmax = -1, 3
        elif "gaussian" in func:
            xmin, xmax = -3, 5
        else:
            xmin, xmax = -1, 1
        x     = np.linspace(xmin, xmax, 201)
        xfit  = x
        y     = np.zeros(len(x))
        noisy = noise(len(x), 0.1)
        uy = noisy
        fitter = fitting.Fit(func, x=x, y=y, uy=uy)
        params = np.ones(fitter.number_of_fitparams)
        y = fitter.func(x, *params) + noisy
        ax.plot(x, y, "-C0", alpha=0.5, label="data")
        fitter = fitting.Fit(func, x=x, y=y, uy=uy)
        y_guess = fitter.func(x, *fitter.guess_params())
        print(fitter.guess_params())
        ax.plot(x, y_guess, "-C1", alpha=0.5, label="guess")
        fit_params, ufit_params = fitter.fit(manualguess_params=None, verbosemode=True)
        yfit = fitter.func(xfit, *fit_params)
        ax.plot(xfit, yfit, "-k", label="fit")
        subtitle = ""
        for key in fitter.params_key:
            subtitle += key+", "
        ax.set_title(func+"\n"+subtitle[:-2])
        ax.legend(loc="upper left", prop={"size":10})
plt.tight_layout()
# Out:
# [[2418.0299999999997, 451.6236484609277], [451.6236484609277, 124.48966590772]]
# [[201, 91.88506627278228], [91.88506627278228, 131.25695137633477]]
# [1.0324227325370172, 0.9811802978901638, 0.007845021916522255]
# [[2418.0299999999997, 451.6236484609277], [451.6236484609277, 124.48966590772]]
# [[201, 91.88506627278228], [91.88506627278228, 131.25695137633477]]
# [1.0324227325370172, 0.9811802978901638, 0.007845021916522255]
# [1.0324227325370172, 0.9811802978901638]
# [[2418.0299999999997, 451.6236484609277], [451.6236484609277, 124.48966590772]]
# [[201, 91.88506627278228], [91.88506627278228, 131.25695137633477]]
# [1.0324227325370172, 0.9811802978901638, 0.007845021916522255]
# ##### Fit results #####
# FIT FUNCTION: exponential
# RAW
#         params_key      : ['scale', 'alpha']
#         optimised params: [0.99989068 1.00025682]
#         uncertainties   : [0.00046094 0.00095262]
#         chi2r           : 1.0089604591151664
#         r2              : 0.9959088856218705
# READABLE
#         scale      = (9.999 +/- 0.005) * 1e-1
#         alpha      = (1.0003 +/- 0.0010) * 1e0
# #######################
# [[2418.0299999999997, 2863.474559021196], [2863.474559021196, 3430.6093531255256]]
# [[201, 91.7196107872041], [91.7196107872041, 121.22714318073642]]
# [0.9547029194447312, 1.0394727713039498, 0.9783817939456794]
# [[2418.0299999999997, 2863.474559021196], [2863.474559021196, 3430.6093531255256]]
# [[201, 91.7196107872041], [91.7196107872041, 121.22714318073642]]
# [0.9547029194447312, 1.0394727713039498, 0.9783817939456794]
# [0.9547029194447312, 1.0394727713039498, 0.9783817939456794]
# [[2418.0299999999997, 2863.474559021196], [2863.474559021196, 3430.6093531255256]]
# [[201, 91.7196107872041], [91.7196107872041, 121.22714318073642]]
# [0.9547029194447312, 1.0394727713039498, 0.9783817939456794]
# ##### Fit results #####
# FIT FUNCTION: exponential_offset
# RAW
#         params_key      : ['scale', 'alpha', 'offset']
#         optimised params: [0.99985633 0.99963792 1.0000273 ]
#         uncertainties   : [0.00060263 0.00086287 0.00018339]
#         chi2r           : 1.012248340269811
#         r2              : 0.9960791778380395
# READABLE
#         scale      = (9.999 +/- 0.006) * 1e-1
#         alpha      = (9.996 +/- 0.009) * 1e-1
#         offset     = (1.0000 +/- 0.0002) * 1e0
# #######################
# [1. 1. 1. 1.]
# ##### Fit results #####
# FIT FUNCTION: gaussian
# RAW
#         params_key      : ['center', 'bandwidth', 'scale', 'offset']
#         optimised params: [1.00177269 0.99779395 0.99934364 1.00016217]
#         uncertainties   : [0.0011228  0.00179039 0.00038511 0.00015498]
#         chi2r           : 0.992138727028079
#         r2              : 0.985601670709763
# READABLE
#         center     = (1.002 +/- 0.001) * 1e0
#         bandwidth  = (9.98 +/- 0.02) * 1e-1
#         scale      = (9.993 +/- 0.004) * 1e-1
#         offset     = (1.0002 +/- 0.0002) * 1e0
# #######################
# [1.0051569125322044, 0.9948206327763045]
# ##### Fit results #####
# FIT FUNCTION: linear
# RAW
#         params_key      : ['slope', 'y0']
#         optimised params: [1.00103296 0.99981752]
#         uncertainties   : [0.00047962 0.00018031]
#         chi2r           : 0.9865740706311529
#         r2              : 0.9951634332432314
# READABLE
#         slope      = (1.0010 +/- 0.0005) * 1e0
#         y0         = (9.998 +/- 0.002) * 1e-1
# #######################
# [1.0, 1.0049221996729218, 2.111656761819343, 0.9985997336869968]
# ##### Fit results #####
# FIT FUNCTION: sin
# RAW
#         params_key      : ['freq', 'scale', 'phi', 'offset']
#         optimised params: [1.00004764 0.99989923 1.00056676 0.99966665]
#         uncertainties   : [0.00019285 0.00040022 0.00054101 0.00034834]
#         chi2r           : 1.0079200061733466
#         r2              : 0.996604915363414
# READABLE
#         freq       = (1.0000 +/- 0.0002) * 1e0
#         scale      = (9.999 +/- 0.004) * 1e-1
#         phi        = (1.0006 +/- 0.0005) * 1e0
#         offset     = (9.997 +/- 0.003) * 1e-1
# #######################
# [1. 1. 1. 1.]
# ##### Fit results #####
# FIT FUNCTION: sinc
# RAW
#         params_key      : ['center', 'freq', 'scale', 'offset']
#         optimised params: [0.99932951 0.99916128 1.00187478 1.00061533]
#         uncertainties   : [0.00033768 0.00044041 0.00156884 0.00045648]
#         chi2r           : 0.98749230968563
#         r2              : 0.9830044120823899
# READABLE
#         center     = (9.993 +/- 0.003) * 1e-1
#         freq       = (9.992 +/- 0.004) * 1e-1
#         scale      = (1.002 +/- 0.002) * 1e0
#         offset     = (1.0006 +/- 0.0005) * 1e0
# #######################
# [1.02, 0.039788735772973836, 1.154733850908767, 0.9130282882689256]
# ##### Fit results #####
# FIT FUNCTION: sinc_squarred
# RAW
#         params_key      : ['center', 'freq', 'scale', 'offset']
#         optimised params: [ 2.68835391  8.54388508 -1.4103607   1.47387135]
#         uncertainties   : [1.71796407e-04 5.61525506e-02 1.80474055e-02 9.47589708e-05]
#         chi2r           : 14982.487309475548
#         r2              : -1.7627676003319355
# READABLE
#         center     = (2.6884 +/- 0.0002) * 1e0
#         freq       = (8.54 +/- 0.06) * 1e0
#         scale      = (-1.41 +/- 0.02) * 1e0
#         offset     = (1.47387 +/- 0.00009) * 1e0
# #######################

# %%
[0,1][:1]
# Out:
# [0]
